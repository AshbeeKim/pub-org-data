# %% [markdown]
# # Guideline

# %% [markdown]
# |    | 공공데이터포털_파일데이터   | 공공데이터포털_오픈API   | 개별기관포털_파일데이터   | 개별기관포털_오픈API   | 작성 기준_메타데이터 비교(메타데이터가 한쪽에 없을 경우, 있는쪽만 작성, 없는 쪽은 빈칸) | 작성 기준_파일데이터 비교  | 작성 기준_오픈API 비교 |
# |---:|:----------------------------|:-----------|:--------------------------|:-----------|:------------------------------------------------------------------------------------------------------------|:--------------------------|:-----------------------------|
# |  1 | O                           | O          | O                         | O          | 파일데이터의 양쪽 포털 메타비교                                                                             | 양쪽 포털                 | 양쪽 포털 API 비교           |
# |  2 | O                           | O          | O                         | X          | 파일데이터의 양쪽 포털 메타비교                                                                             | 양쪽 포털                 | 공공 API 작성, 개별API 빈칸  |
# |  3 | O                           | O          | X                         | O          | 양쪽 포털 API데이터의 메타비교                                                                              | 공공 파일 작성, 개별 빈칸 | 양쪽 포털 API 비교           |
# |  4 | O                           | X          | O                         | O          | 양쪽 포털 파일데이터의 메타비교                                                                             | 양쪽 포털                 | 공공 API 빈칸, 개별 API 작성 |
# |  5 | O                           | X          | O                         | X          | 양쪽 포털 파일데이터의 메타비교                                                                             | 양쪽 포털                 | X                            |
# |  6 | O                           | X          | X                         | O          | 공공 파일데이터 메타, 개별 API 메타비교                                                                     | 공공 파일 작성, 개별 빈칸 | 공공 API 빈칸, 개별 API 작성 |
# |  7 | X                           | O          | O                         | O          | 양쪽 포털 API데이터의 메타비교                                                                              | 공공 빈칸, 개별 파일 작성 | 양쪽 포털 API 비교           |
# |  8 | X                           | O          | O                         | X          | 공공 API 메타, 개별 파일 메타비교                                                                           | 공공 빈칸, 개별 파일 작성 | 공공 API작성, 개별 빈칸      |
# |  9 | X                           | O          | X                         | O          | 양쪽 포털 API데이터의 메타비교                                                                              | X                         | 양쪽 포털 API 비교           |
# | 10 | X                           | X          | O                         | O          | 공공 빈칸, 개별 파일 메타비교(O없으면 작성x)                                                                | 공공 빈칸, 개별 파일 작성 | 공공 API 빈칸, 개별 API 작성 |
# | 11 | X                           | X          | O                         | X          | 공공 빈칸, 개별 파일 메타비교(O없으면 작성x)                                                                | 공공 빈칸, 개별 파일 작성 | X                            |
# | 12 | X                           | X          | X                         | O          | 공공 빈칸, 개별API 메타비교(O없으면 작성x)                                                                  | X                         | 공공 API 빈칸, 개별 API 작성 |
# | 13 | O                           | O          | X                         | X          | 공공 파일, 개별 빈칸 메타비교(O없으면 작성x)                                                                | 공공 파일 작성, 개별 빈칸 | 공공 API작성, 개별 빈칸      |
# | 14 | O                           | X          | X                         | X          | 공공 파일, 개별 빈칸 메타비교(O없으면 작성x)                                                                | 공공 파일 작성, 개별 빈칸 | X                            |
# | 15 | X                           | O          | X                         | X          | 공공 API, 개별 빈칸 메타비교(O없으면 작성x)                                                                 | X                         | 공공 API작성, 개별 빈칸      |
# | 16 | X                           | X          | X                         | X          | 배정목록 검색결과 조사유형(FILE,API)이 아니거나 없을 경우 [수련생ID,수련생 이름, 목록명]만 제출해 주십시오. | nan                       | nan

# %% [markdown]
# # 2021.Nov.22
# |    | 기관명         | 사이트명                                      | 파일 목록명                                               | 확장자   | 포털 메뉴                                                            | 제공방식 구분   |   로그인계정 |
# |---:|:---------------|:----------------------------------------------|:----------------------------------------------------------|:---------|:---------------------------------------------------------------------|:----------------|-------------:|
# |  0 | 농림축산식품부 | 농식품 공공데이터포털  data.mafra.go.kr       | 한국농어촌공사_농업용저수지 수질정보_공사조사수질(2016년) | 파일     | 공공데이터>서비스유형(File(파일))                                    | 개방            |          nan |
# |  1 | 대구광역시     | D-데이터허브 data.daegu.go.kr                 | 6270000_대구광역시_09_28_06_P_석연탄제조업_9월            | 파일     | 데이터이용>데이터 상세검색>전체 카테고리>FILE                        | 개방            |          nan |
# |  2 | 대구광역시     | D-데이터허브 data.daegu.go.kr                 | 6270000_대구광역시_09_28_06_P_석연탄제조업_9월            | 파일     | 데이터이용>데이터 상세검색>전체 카테고리>FILE                        | 개방            |          nan |
# |  3 | 대구광역시     | D-데이터허브 data.daegu.go.kr                 | 6270000_대구광역시_09_28_06_P_석연탄제조업_9월            | 파일     | 데이터이용>데이터 상세검색>전체 카테고리>FILE                        | 개방            |          nan |
# |  4 | 대구광역시     | D-데이터허브 data.daegu.go.kr                 | 6270000_대구광역시_09_28_06_P_석연탄제조업_9월            | 파일     | 데이터이용>데이터 상세검색>전체 카테고리>FILE                        | 개방            |          nan |
# |  5 | 대구광역시     | D-데이터허브 data.daegu.go.kr                 | 6270000_대구광역시_09_28_06_P_석연탄제조업_9월            | 파일     | 데이터이용>데이터 상세검색>전체 카테고리>FILE                        | 개방            |          nan |
# |  6 | 대구광역시     | D-데이터허브 data.daegu.go.kr                 | 대구광역시_서구_협동조합 현황_20191016                    | 파일     | 데이터이용>데이터 상세검색>전체 카테고리>FILE                        | 개방            |          nan |
# |  7 | 서울특별시     | 열린데이터광장 (25개 자치구) data.seoul.go.kr | 서울특별시 관악구 동물용의료용구판매업 인허가 정보        | 파일     | 공공데이터>데이터셋>제공유형(SHEET)                                  | 개방            |          nan |
# |  8 | 서울특별시     | 열린데이터광장 (25개 자치구) data.seoul.go.kr | 서울특별시 관악구 동물용의료용구판매업 인허가 정보        | API      | 공공데이터>데이터셋>제공유형(API)                                    | 개방            |          nan |
# |  9 | 서울특별시     | 열린데이터광장 (25개 자치구) data.seoul.go.kr | 서울특별시 노원구 건물위생관리업 인허가 정보              | 파일     | 공공데이터>데이터셋>제공유형(SHEET)                                  | 개방            |          nan |
# | 10 | 서울특별시     | 열린데이터광장 (25개 자치구) data.seoul.go.kr | 서울특별시 노원구 건물위생관리업 인허가 정보              | API      | 공공데이터>데이터셋>제공유형(API)                                    | 개방            |          nan |
# | 11 | 전라북도       | 전북빅데이터허브 www.bigdatahub.go.kr         | 시군별 기업유치 현황(2016.3)                              | 파일     | 공공데이터>데이터셋>전체 목록 중 CSV, XLS, FILE 데이터만 파일로 취급 | 개방            |          nan |

# %% [markdown]
# # 2021.Nov.19
# |    | 기관명         | 사이트명                                               | 파일 목록명                      | 확장자   | 포털 메뉴                                                                               | 제공방식 구분   |   로그인계정 |
# |---:|:---------------|:-------------------------------------------------------|:---------------------------------|:---------|:----------------------------------------------------------------------------------------|:----------------|-------------:|
# |  0 | 한국임업진흥원 | 산림 빅데이터플랫폼(www.bigdata-forest.kr)             | 산림재해 관심인구 정보           | 파일     | 데이터상품>이용조건(무료) 체크 후 검색                                                  | 개방            |          nan |
# |  1 | 통계청         | e-나라지표 www.index.go.kr                             | 정부위원회 여성참여율            | 파일     | 서비스소개>e-나라지표 체계>부처별 지표체계> 부처별지표체계도 전체 다운로드> 각 URL 이용 | 통계            |          nan |
# |  2 | 인천시         | 인천데이터포털  www.incheon.go.kr/data                 | 인천광역시_연수구_병의원 현황    | 파일     | 데이터 개방>공공데이터                                                                  | 개방            |          nan |
# |  3 | 농림축산식품부 | 농식품 공공데이터포털  data.mafra.go.kr                | 식품·유통R&D 논문정보            | 파일     | 공공데이터>서비스유형(File(파일))                                                       | 개방            |          nan |
# |  4 | 농림축산식품부 | 농식품 공공데이터포털  data.mafra.go.kr                | 식품·유통R&D 논문정보            | API      | 공공데이터>서비스유형(OpenAPI)                                                          | 개방            |          nan |
# |  5 | 기획재정부     | 재정정보공개시스템 (열린재정) www.openfiscaldata.go.kr | 토지(금액)                       | API      | 재정통계>주요재정통계>주요지표별>국유재산 현황                                          | 개방            |          nan |
# |  6 | 경기도         | 경기데이터드림  data.gg.go.kr                          | 음식 문화개선 특화 거리지정 현황 | API      | 데이터>데이터셋                                                                         | 개방            |          nan |
# |  7 | 경기도         | 경기데이터드림  data.gg.go.kr                          | 음식 문화개선 특화 거리지정 현황 | 파일     | 데이터>데이터셋                                                                         | 개방            |          nan |

# %% [markdown]
# # 2021.Nov.18
# |    | 기관명             | 사이트명                                      | 파일 목록명                                                 | 확장자   | 포털 메뉴                               | 제공방식 구분   |   로그인계정 |
# |---:|:-------------------|:----------------------------------------------|:------------------------------------------------------------|:---------|:----------------------------------------|:----------------|-------------:|
# |  0 | 광양시             | 광양시 공공데이터포털 gwangyang.go.kr/data    | 전라남도 광양시_민방위대피시설                              | API      | 공공데이터>오픈API                      | 개방            |          nan |
# |  1 | 서울특별시         | 열린데이터광장 (25개 자치구) data.seoul.go.kr | 서울시 청소년 손상 및 안전의식 통계                         | 파일     | 공공데이터>데이터셋>제공유형(SHEET)     | 개방            |          nan |
# |  2 | 서울특별시         | 열린데이터광장 (25개 자치구) data.seoul.go.kr | 서울시립미술관 SeMA매거진 정보(영문)                        | 파일     | 공공데이터>데이터셋>제공유형(SHEET)     | 개방            |          nan |
# |  3 | 서울특별시         | 열린데이터광장 (25개 자치구) data.seoul.go.kr | 서울시립미술관 SeMA매거진 정보(영문)                        | API      | 공공데이터>데이터셋>제공유형(API)       | 개방            |          nan |
# |  4 | 서울특별시         | 열린데이터광장 (25개 자치구) data.seoul.go.kr | 서울특별시 강남구 쓰레기종량제봉투판매업 인허가 정보        | 파일     | 공공데이터>데이터셋>제공유형(SHEET)     | 개방            |          nan |
# |  5 | 서울특별시         | 열린데이터광장 (25개 자치구) data.seoul.go.kr | 서울특별시 강남구 쓰레기종량제봉투판매업 인허가 정보        | API      | 공공데이터>데이터셋>제공유형(API)       | 개방            |          nan |
# |  6 | 한국여성정책연구원 | 성인지통계 gsis.kwdi.re.kr                    | 업무상재해 부상자 및 사망자(성/산업별)_2000~2006            | 파일     | 통계DB>주제별>경제활동>고용안정         | 통계            |          nan |
# |  7 | 해양 수산부        | 해양수산 빅데이터 플랫폼 www.vadahub.go.kr    | 선박스케줄 수집정보_해양수산부(해운항만물류정보센터(SP-IDC) | 파일     | 해양수산정보 검색>데이터 소재 검색>전체 | 개방            |          nan |

# %% [markdown]
# # 2021.Nov.17
#
# |    | 기관명                 | 사이트명                                            | 파일 목록명                                                      | 확장자   | 포털 메뉴                                                                                          | 제공방식 구분   |   로그인계정 |
# |---:|:-----------------------|:----------------------------------------------------|:-----------------------------------------------------------------|:---------|:---------------------------------------------------------------------------------------------------|:----------------|-------------:|
# |  0 | 해양 수산부            | 해양수산 빅데이터 플랫폼 www.vadahub.go.kr          | 인공지능연속정보(해상풍)_해양수산부(해양공간정보체계)            | 파일     | 해양수산정보 검색>데이터 소재 검색>전체                                                            | 개방            |          nan |
# |  1 | 해양 수산부            | 해양수산 빅데이터 플랫폼 www.vadahub.go.kr          | 연도별 최대태풍 해일고_국립해양조사원(연안재해취약성 평가시스템) | 파일     | 해양수산정보 검색>데이터 소재 검색>전체                                                            | 개방            |          nan |
# |  2 | 한국문화관광연구원     | 문화셈터 stat.mcst.go.kr                            | 휴일 유형별 희망하는 여가활동 유형(복수응답)                     | 파일     | 주제별통계>문화예술통계>국민여가활동조사                                                           | 통계            |          nan |
# |  3 | 한국문화관광연구원     | 문화셈터 stat.mcst.go.kr                            | 봉사활동 참여 의향                                               | 파일     | 주제별통계>문화예술통계>국민여가활동조사                                                           | 통계            |          nan |
# |  4 | 한국과학기술정보연구원 | ScienceOn API Gateway apigateway.kisti.re.kr        | 출원인/링크리졸버                                                | API      | 활용방법>OpenAPI>상세이용안내>출원인/링크리졸버>출원인 검색API, 링크리졸버API                      | 개방            |          nan |
# |  5 | 통계청                 | e-나라지표 www.index.go.kr                          | 노인일자리 및 노후생활 현황                                      | 파일     | 서비스소개>e-나라지표 체계>부처별 지표체계> 부처별지표체계도 전체 다운로드> 각 URL 이용            | 통계            |          nan |
# |  6 | 인천시                 | 인천데이터포털  www.incheon.go.kr/data              | 인천광역시 남동구_옥외광고물 기관코드                            | 파일     | 데이터 개방>공공데이터                                                                             | 개방            |          nan |
# |  7 | 서울특별시             | 열린데이터광장 (25개 자치구) data.seoul.go.kr       | 서울시 특별회계 세입세출 예산개요 (본청) 통계                    | 파일     | 공공데이터>데이터셋>제공유형(SHEET)                                                                | 개방            |          nan |
# |  8 | 부산광역시             | 부산 공공데이터 포털 data.busan.go.kr               | 부산교통공사_부산도시철도 역사 건축현황                          | 파일     | 데이터>데이터셋>서비스유형(SHEET, FILE), 분류별(전체), 제공기관별(전체) 체크 후 검색               | 개방            |          nan |
# |  9 | 부산광역시             | 부산 공공데이터 포털 data.busan.go.kr               | 부산광역시_명절 무료주차장 현황(SHP)                             | 파일     | 데이터>데이터셋>서비스유형(SHEET, FILE), 분류별(전체), 제공기관별(전체) 체크 후 검색               | 개방            |          nan |
# | 10 | 경상남도               | 경상남도 빅데이터 허브 포털 bigdata.gyeongnam.go.kr | 경상남도_전세버스 운송사업 업체 현황                             | 파일     | 공공데이터>공공데이터검색>서비스유형(SHEET, FILE), 분류별(전체), 제공기관별(전체), 외부기관제공(x) | 개방            |          nan |
# | 11 | 경기도청               | 지역경제 빅데이터플랫폼(www.bigdata-region.kr)      | 연령별 인구 현황                                                 | 파일     | 데이터셋>가격(무료)    |    개방    |        nan |

# %% [markdown]
# # 2021.Nov.16
# |    | 기관명                 | 사이트명                                       | 파일 목록명                                         | 확장자   | 포털 메뉴                                                                            | 제공방식 구분   |   로그인계정 |
# |---:|:-----------------------|:-----------------------------------------------|:----------------------------------------------------|:---------|:-------------------------------------------------------------------------------------|:----------------|-------------:|
# |  0 | 한국임업진흥원         | 산림 빅데이터플랫폼(www.bigdata-forest.kr)     | 수도권 버스정류장 그룹간 경로                       | 파일     | 데이터상품>이용조건(무료) 체크 후 검색                                               | 개방            |          nan |
# |  1 | 한국과학기술정보연구원 | R&D데이터 개방 ntis.go.kr                      | 제작국가별 투자현황                                 | 파일     | 데이터활용>과학기술통계>연구시설장비                                                 | 개방/통계       |          nan |
# |  2 | 테크노파크             | 제주데이터허브 jejudatahub.net                 | 제주특별자치도 문화재 지정 현황                     | 파일     | 데이터>데이터 유형(파일) 체크                                                        | 개방            |          nan |
# |  3 | 전라북도               | 전북빅데이터허브 www.bigdatahub.go.kr          | 전라북도 건설업 현황(2017.02월)                     | 파일     | 공공데이터>데이터셋>전체 목록 중 CSV, XLS, FILE 데이터만 파일로 취급                 | 개방            |          nan |
# |  4 | 전라북도               | 전북빅데이터허브 www.bigdatahub.go.kr          | 연령별 어린이집 이용 현황                           | 파일     | 공공데이터>데이터셋>전체 목록 중 CSV, XLS, FILE 데이터만 파일로 취급                 | 개방            |          nan |
# |  5 | 인천시                 | 인천데이터포털  www.incheon.go.kr/data         | 인천광역시_계양구_방문판매업                        | 파일     | 데이터 개방>공공데이터                                                               | 개방            |          nan |
# |  6 | 서울특별시             | 열린데이터광장 (25개 자치구) data.seoul.go.kr  | 서울시 용산구 노동조합 현황                         | 파일     | 공공데이터>데이터셋>제공유형(SHEET)                                                  | 개방            |          nan |
# |  7 | 서울특별시             | 열린데이터광장 (25개 자치구) data.seoul.go.kr  | 서울시 용산구 노동조합 현황                         | API      | 공공데이터>데이터셋>제공유형(API)                                                    | 개방            |          nan |
# |  8 | 서울특별시             | 열린데이터광장 (25개 자치구) data.seoul.go.kr  | 서울시 연평균기온 2008년 위치정보 (좌표계: WGS1984) | 파일     | 공공데이터>데이터셋>제공유형(SHEET)                                                  | 개방            |          nan |
# |  9 | 서울특별시             | 열린데이터광장 (25개 자치구) data.seoul.go.kr  | 서울시 연평균기온 2008년 위치정보 (좌표계: WGS1984) | API      | 공공데이터>데이터셋>제공유형(API)                                                    | 개방            |          nan |
# | 10 | 부산광역시             | 부산 공공데이터 포털 data.busan.go.kr          | 부산광역시_부산진구_동물병원현황                    | 파일     | 데이터>데이터셋>서비스유형(SHEET, FILE), 분류별(전체), 제공기관별(전체) 체크 후 검색 | 개방            |          nan |
# | 11 | 대구광역시             | D-데이터허브 data.daegu.go.kr                  | 6270000_대구광역시_09_28_06_P_석연탄제조업_7월      | 파일     | 데이터이용>데이터 상세검색>전체 카테고리>FILE                                        | 개방            |          nan |
# | 12 | 대구광역시             | D-데이터허브 data.daegu.go.kr                  | 6270000_대구광역시_09_28_06_P_석연탄제조업_7월      | 파일     | 데이터이용>데이터 상세검색>전체 카테고리>FILE                                        | 개방            |          nan |
# | 13 | 대구광역시             | D-데이터허브 data.daegu.go.kr                  | 6270000_대구광역시_03_05_07_P_청소년게임제공업_3월  | 파일     | 데이터이용>데이터 상세검색>전체 카테고리>FILE                                        | 개방            |          nan |
# | 14 | 대구광역시             | D-데이터허브 data.daegu.go.kr                  | 6270000_대구광역시_03_05_07_P_청소년게임제공업_3월  | 파일     | 데이터이용>데이터 상세검색>전체 카테고리>FILE                                        | 개방            |          nan |
# | 15 | 국립암센터             | 헬스케어 빅데이터플랫폼(www.bigdata-cancer.kr) | 장내미생물_DB (서울대학교산학협력단)                | 파일     | 데이터 조회>테이블 현황                                                              | 개방            |          nan |

# %% [markdown]
# # 2021.Nov.15
# |    | 기관명             | 사이트명                              | 파일 목록명                                                    | 확장자   | 포털 메뉴                                                                            | 제공방식 구분   |   로그인계정 |
# |---:|:-------------------|:--------------------------------------|:---------------------------------------------------------------|:---------|:-------------------------------------------------------------------------------------|:----------------|-------------:|
# |  0 | 한국전력거래소     | 전력통계정보시스템 epsis.kpx.or.kr    | 화력발전소열효율                                               | 파일     | 발전·판매>화력발전소열효율                                                           | 통계            |          nan |
# |  1 | 한국여성정책연구원 | 성인지통계 gsis.kwdi.re.kr            | 해외여행 경험 및 횟수(성/연령·교육정도·혼인상태별)_2004년 이후 | 파일     | 통계DB>주제별>문화 및 정보>여가활동                                                  | 통계            |          nan |
# |  2 | 부산광역시         | 부산 공공데이터 포털 data.busan.go.kr | 부산광역시_금정구_장례시설현황                                 | 파일     | 데이터>데이터셋>서비스유형(SHEET, FILE), 분류별(전체), 제공기관별(전체) 체크 후 검색 | 개방            |          nan |
# |  3 | 부산광역시         | 부산 공공데이터 포털 data.busan.go.kr | 부산광역시_금정구_마을회관 및 경로당 현황                      | 파일     | 데이터>데이터셋>서비스유형(SHEET, FILE), 분류별(전체), 제공기관별(전체) 체크 후 검색 | 개방            |          nan |
# |  4 | 대구광역시         | D-데이터허브 data.daegu.go.kr         | 대구광역시 건축허가 및 착공통계_20200531                       | 파일     | 데이터이용>데이터 상세검색>전체 카테고리>FILE                                        | 개방            |          nan |
# |  5 | 경기도             | 경기데이터드림  data.gg.go.kr         | 예비비 확보율 현황                                             | API      | 데이터>데이터셋                                                                      | 개방            |          nan |
# |  6 | 경기도             | 경기데이터드림  data.gg.go.kr         | 예비비 확보율 현황                                             | 파일     | 데이터>데이터셋                                                                      | 개방            |          nan |

# %% [markdown]
# # 2021.Nov.12
# |    | 기관명                  | 사이트명                                      | 파일 목록명                                  | 확장자   | 포털 메뉴                                                                            | 제공방식 구분   |   로그인계정 |
# |---:|:------------------------|:----------------------------------------------|:---------------------------------------------|:---------|:-------------------------------------------------------------------------------------|:----------------|-------------:|
# |  0 | 국토교통부              | 국가공간정보포털  nsdi.go.kr                  | 행정구역시군구_경계                          | 파일     | 개방공간>오픈마켓>좌측하단 포멧>XLSX                                                 | 개방            |          nan |
# |  1 | 부산광역시              | 부산 공공데이터 포털 data.busan.go.kr         | 부산광역시_중구_가로수 현황                  | 파일     | 데이터>데이터셋>서비스유형(SHEET, FILE), 분류별(전체), 제공기관별(전체) 체크 후 검색 | 개방            |          nan |
# |  2 | 서울특별시              | 열린데이터광장 (25개 자치구) data.seoul.go.kr | 서울시 동작구 모범음식점 지정 현황           | 파일     | 공공데이터>데이터셋>제공유형(SHEET)                                                  | 개방            |          nan |
# |  3 | 서울특별시              | 열린데이터광장 (25개 자치구) data.seoul.go.kr | 서울시 동작구 모범음식점 지정 현황           | API      | 공공데이터>데이터셋>제공유형(API)                                                    | 개방            |          nan |
# |  4 | 서울특별시              | 열린데이터광장 (25개 자치구) data.seoul.go.kr | 청계천 역사문화 비콘정보                     | 파일     | 공공데이터>데이터셋>제공유형(FILE)>SHEET가 포함되어 있지 않은 데이터(534건 중 190건) | 개방            |          nan |
# |  5 | 한국방송통신 전파진흥원 | 오픈API센터 data.kca.kr                       | 지역별 의무측정무선국에 따른 전자파 노출지수 | API      | 오픈API>전자파 안전정보                                                              | 개방            |          nan |

# %% [markdown]
# # 2021.Nov.11
# |    | 기관명             | 사이트명                                        | 파일 목록명                                                                           | 확장자   | 포털 메뉴                                                            | 제공방식 구분   |   로그인계정 |
# |---:|:-------------------|:------------------------------------------------|:--------------------------------------------------------------------------------------|:---------|:---------------------------------------------------------------------|:----------------|-------------:|
# |  0 | 서울특별시         | 열린데이터광장 (25개 자치구) data.seoul.go.kr   | 서울특별시 도봉구 건물위생관리업 인허가 정보                                          | 파일     | 공공데이터>데이터셋>제공유형(SHEET)                                  | 개방            |          nan |
# |  1 | 서울특별시         | 열린데이터광장 (25개 자치구) data.seoul.go.kr   | 서울특별시 도봉구 건물위생관리업 인허가 정보                                          | API      | 공공데이터>데이터셋>제공유형(API)                                    | 개방            |          nan |
# |  2 | 인천시             | 인천데이터포털  www.incheon.go.kr/data          | 인천광역시 중구_자원봉사시설 현황                                                     | 파일     | 데이터 개방>공공데이터                                               | 개방            |          nan |
# |  3 | 전라북도           | 전북빅데이터허브 www.bigdatahub.go.kr           | 시군별 심폐소생술 교육 현황 (2015년)                                                  | 파일     | 공공데이터>데이터셋>전체 목록 중 CSV, XLS, FILE 데이터만 파일로 취급 | 개방            |          nan |
# |  4 | 한국문화관광연구원 | 문화셈터 stat.mcst.go.kr                        | 온라인광고대행업 세부 업무 분야별 취급액(매출액) 총계 - 온라인 광고 제작대행 - 권역별 | 파일     | 주제별통계>문화산업통계>광고산업조사                                 | 통계            |          nan |
# |  5 | 한국산업기술시험원 | 디지털산업혁신빅데이터플랫폼(www.bigdata-dx.kr) | 공인회계사감사의견                                                                    | 파일     | 데이터 상품>무료데이터                                               | 개방            |          nan |
# |  6 | 행정안전부         | 생활안전지도 safemap.go.kr                      | 사고발생_화재사고_차량화재 추이                                                       | 파일     | 생활안전통계>사고발생                                                | 통계            |          nan |

# %% [markdown]
# # 2021.Nov.10
# |    | 기관명             | 사이트명                                       | 파일 목록명                                          | 확장자   | 포털 메뉴                                     | 제공방식 구분   |   로그인계정 |
# |---:|:-------------------|:-----------------------------------------------|:-----------------------------------------------------|:---------|:----------------------------------------------|:----------------|-------------:|
# |  0 | 한국문화관광연구원 | 문화셈터 stat.mcst.go.kr                       | 여행지별 당일 개인여행 체험 프로그램 만족도(2014~)   | 파일     | 주제별통계>관광통계>국민여행조사              | 통계            |          nan |
# |  1 | 서울특별시         | 열린데이터광장 (25개 자치구) data.seoul.go.kr  | 서울시 광진구 진료 공공서비스예약 정보               | 파일     | 공공데이터>데이터셋>제공유형(SHEET)           | 개방            |          nan |
# |  2 | 서울특별시         | 열린데이터광장 (25개 자치구) data.seoul.go.kr  | 서울시 광진구 진료 공공서비스예약 정보               | API      | 공공데이터>데이터셋>제공유형(API)             | 개방            |          nan |
# |  3 | 서울특별시         | 열린데이터광장 (25개 자치구) data.seoul.go.kr  | 서울시 하이서울페스티발 인지도 통계                  | 파일     | 공공데이터>데이터셋>제공유형(SHEET)           | 개방            |          nan |
# |  4 | 서울특별시         | 열린데이터광장 (25개 자치구) data.seoul.go.kr  | 서울특별시 성북구 유치원 교실면적 현황               | 파일     | 공공데이터>데이터셋>제공유형(SHEET)           | 개방            |          nan |
# |  5 | 서울특별시         | 열린데이터광장 (25개 자치구) data.seoul.go.kr  | 서울특별시 성북구 유치원 교실면적 현황               | API      | 공공데이터>데이터셋>제공유형(API)             | 개방            |          nan |
# |  6 | 경기도             | 경기데이터드림  data.gg.go.kr                  | 한강권역 보 관측 정보                                | API      | 데이터>데이터셋                               | 개방            |          nan |
# |  7 | 경기도             | 경기데이터드림  data.gg.go.kr                  | 한강권역 보 관측 정보                                | 파일     | 데이터>데이터셋                               | 개방            |          nan |
# |  8 | 경기도청           | 지역경제 빅데이터플랫폼(www.bigdata-region.kr) | SNS 고용단어빈도                                     | 파일     | 데이터셋>가격(무료)                           | 개방            |          nan |
# |  9 | 해양 수산부        | 해양수산 빅데이터 플랫폼 www.vadahub.go.kr     | 통항분리경계선_국립해양조사원(개방해)                | 파일     | 해양수산정보 검색>데이터 소재 검색>전체       | 개방            |          nan |
# | 10 | 국립암센터         | 헬스케어 빅데이터플랫폼(www.bigdata-cancer.kr) | 대장암_치료_항암제_Adjuvant (대구가톨릭대학교의료원) | 파일     | 데이터 조회>테이블 현황                       | 개방            |          nan |
# | 11 | 국립해양조사원     | 개방해-국가해양정보마켓센터 khoa.go.kr/komc    | 용정리(함평만) 비실시간 장단기 조위                  | 파일     | 해양정보>데이터셋 검색>무료>CSV               | 개방            |          nan |
# | 12 | 대구광역시         | D-데이터허브 data.daegu.go.kr                  | 6270000_대구광역시_09_30_14_P_저수조청소업_12월      | 파일     | 데이터이용>데이터 상세검색>전체 카테고리>FILE | 개방            |          nan |
# | 13 | 대구광역시         | D-데이터허브 data.daegu.go.kr                  | 6270000_대구광역시_09_30_14_P_저수조청소업_12월      | 파일     | 데이터이용>데이터 상세검색>전체 카테고리>FILE | 개방            |          nan |
# | 14 | 대구광역시         | D-데이터허브 data.daegu.go.kr                  | 대구광역시 중구_자치구 내 소독업체 현황_20210415     | 파일     | 데이터이용>데이터 상세검색>전체 카테고리>FILE | 개방            |          nan |

# %% [markdown]
# # 2021.Nov.09
# |    | 기관명             | 사이트명                                            | 파일 목록명                                                 | 확장자   | 포털 메뉴                                                                                          | 제공방식 구분   |   로그인계정 |
# |---:|:-------------------|:----------------------------------------------------|:------------------------------------------------------------|:---------|:---------------------------------------------------------------------------------------------------|:----------------|-------------:|
# |  0 | 강원도             | 강원 공공데이터 포털 data.gwd.go.kr                 | 48. 강원도 거주자우선 주차정보                              | 파일     | Dataset>전체데이터>전체조건 클릭>서비스형태(SHEET, FILE)                                           | 개방            |          nan |
# |  1 | 강원도             | 강원 공공데이터 포털 data.gwd.go.kr                 | 48. 강원도 거주자우선 주차정보                              | API      | Dataset>전체데이터>전체조건 클릭>서비스형태(Open API)                                              | 개방            |          nan |
# |  2 | 경상남도           | 경상남도 빅데이터 허브 포털 bigdata.gyeongnam.go.kr | 경상남도_거창군_국내자매결연현황                            | 파일     | 공공데이터>공공데이터검색>서비스유형(SHEET, FILE), 분류별(전체), 제공기관별(전체), 외부기관제공(x) | 개방            |          nan |
# |  3 | 대구광역시         | D-데이터허브 data.daegu.go.kr                       | 6270000_대구광역시_09_28_09_P_액화석유가스용품제조업체_12월 | 파일     | 데이터이용>데이터 상세검색>전체 카테고리>FILE                                                      | 개방            |          nan |
# |  4 | 대구광역시         | D-데이터허브 data.daegu.go.kr                       | 6270000_대구광역시_09_28_09_P_액화석유가스용품제조업체_12월 | 파일     | 데이터이용>데이터 상세검색>전체 카테고리>FILE                                                      | 개방            |          nan |
# |  5 | 대구광역시         | D-데이터허브 data.daegu.go.kr                       | 대구광역시 북구_다문화유관기관_20201209                     | 파일     | 데이터이용>데이터 상세검색>전체 카테고리>FILE                                                      | 개방            |          nan |
# |  6 | 부산광역시         | 부산 공공데이터 포털 data.busan.go.kr               | 부산광역시 사상구 급경사지 정보                             | 파일     | 데이터>데이터셋>서비스유형(SHEET, FILE), 분류별(전체), 제공기관별(전체) 체크 후 검색               | 개방            |          nan |
# |  7 | 부산광역시         | 부산 공공데이터 포털 data.busan.go.kr               | 부산광역시 영도구_폐기물 배출업소 현황                      | 파일     | 데이터>데이터셋>서비스유형(SHEET, FILE), 분류별(전체), 제공기관별(전체) 체크 후 검색               | 개방            |          nan |
# |  8 | 통계청             | e-나라지표 www.index.go.kr                          | 음주 및 흡연현황                                            | 파일     | 서비스소개>e-나라지표 체계>부처별 지표체계> 부처별지표체계도 전체 다운로드> 각 URL 이용            | 통계            |          nan |
# |  9 | 한국문화관광연구원 | 문화셈터 stat.mcst.go.kr                            | 2010년 관광편의시설업 전자상거래 현황                       | 파일     | 주제별통계>관광통계>관광산업조사                                                                   | 통계            |          nan |
# | 10 | 한국문화관광연구원 | 문화셈터 stat.mcst.go.kr                            | 관광 당일여행 여행사 상품 구매 여부                         | 파일     | 주제별통계>관광통계>국민여행조사                                                                   | 통계            |          nan |
# | 11 | 한국문화관광연구원 | 문화셈터 stat.mcst.go.kr                            | 여행지별 숙박 개인여행 관광정보 및 안내시설 만족도(2014~)   | 파일     | 주제별통계>관광통계>국민여행조사                                                                   | 통계            |          nan |
# | 12 | 한국문화관광연구원 | 문화셈터 stat.mcst.go.kr                            | 체지방률 변화: 초등학생 여자                                | 파일     | 주제별통계>체육통계>국민체력측정통계                                                               | 통계            |          nan |
# | 13 | 해양 수산부        | 해양수산 빅데이터 플랫폼 www.vadahub.go.kr          | 연안관리지역계획_해양수산부(연안관리정보시스템)             | 파일     | 해양수산정보 검색>데이터 소재 검색>전체                                                            | 개방            |          nan |

# %% [markdown]
# # 2021.Nov.08
# |    | 기관명             | 사이트명                                           | 파일 목록명                                                   | 확장자   | 포털 메뉴                                     | 제공방식 구분   |   로그인계정 |
# |---:|:-------------------|:---------------------------------------------------|:--------------------------------------------------------------|:---------|:----------------------------------------------|:----------------|-------------:|
# |  0 | 경기도청           | 지역경제 빅데이터플랫폼(www.bigdata-region.kr)     | SNS 관광근접단어빈도                                          | 파일     | 데이터셋>가격(무료)                           | 개방            |          nan |
# |  1 | 국립공원공단       | 국립공원 자원정보 개방서비스knps.or.kr/reinfo/pios | 2017년 지리산 포유류                                          | 파일     | 데이터셋>공원자원>생물자원                    | 개방            |          nan |
# |  2 | 국립공원공단       | 국립공원 자원정보 개방서비스knps.or.kr/reinfo/pios | 다도해해상국립공원 신앙                                       | 파일     | 데이터셋>공원자원>문화자원                    | 개방            |          nan |
# |  3 | 국립암센터         | 헬스케어 빅데이터플랫폼(www.bigdata-cancer.kr)     | 갑상선암 호르몬치료 종류별 환자수                             | API      | 데이터 신청>오픈 API 신청>오픈 API 목록       | 개방            |          nan |
# |  4 | 대구광역시         | D-데이터허브 data.daegu.go.kr                      | 6270000_대구광역시_02_04_06_P_종축업_3월                      | 파일     | 데이터이용>데이터 상세검색>전체 카테고리>FILE | 개방            |          nan |
# |  5 | 대구광역시         | D-데이터허브 data.daegu.go.kr                      | 6270000_대구광역시_02_04_06_P_종축업_3월                      | 파일     | 데이터이용>데이터 상세검색>전체 카테고리>FILE | 개방            |          nan |
# |  6 | 한국문화관광연구원 | 문화셈터 stat.mcst.go.kr                           | 여가생활에 만족하지 못하는 이유-여가생활에 만족하지 못하는 자 | 파일     | 주제별통계>문화예술통계>국민여가활동조사      | 통계            |          nan |
